# %%
# !pip install --upgrade pip
# !pip uninstall -y enum34
# !pip install --upgrade pyproj pandas shapely geopandas dask_ml joblib==0.15.1 scikit-learn==0.23.1 dask[dataframe]==2.12.0 distributed==2.12.0 lz4==3.0.2 blosc==1.8.3 cloudpickle==1.3.0 msgpack==1.0.0 numpy==1.18.1 toolz==0.10.0 tornado==6.0.4 imbalanced-learn pyzmq
# Out:
# Requirement already up-to-date: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (20.1.1)
# WARNING: Skipping enum34 as it is not installed.
# Requirement already up-to-date: pyproj in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.6.1.post1)
# Requirement already up-to-date: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.0.3)
# Requirement already up-to-date: shapely in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.7.0)
# Requirement already up-to-date: geopandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.7.0)
# Requirement already up-to-date: dask_ml in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.4.0)
# ...
#      |████████████████████████████████| 298 kB 16.1 MB/s eta 0:00:01
# Requirement already up-to-date: scikit-learn==0.23.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.23.1)
# ...

# %%
# !pip install wrapt --upgrade --ignore-installed
# !pip install --upgrade keras==2.1.5 tensorflow==2.0
# Out:
# ...
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=65806 sha256=55fcc1bcf0661aecf48fab32b49fa452a39d0e79c639f4bd003a6183147fdf20
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built wrapt
# ...
#      |████████████████████████████████| 334 kB 17.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 86.3 MB 89 kB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 3.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 3.8 MB 75.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 8.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 2.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 50 kB 12.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 104 kB 65.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 32.7 MB/s eta 0:00:01
# ...

# %%
# !pip install talos
# Out:
# ...
#      |████████████████████████████████| 53 kB 3.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 109.2 MB 7.7 kB/s  eta 0:00:01   |██▋                             | 8.9 MB 37.9 MB/s eta 0:00:03
# ...
#      |████████████████████████████████| 8.7 MB 62.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 377 kB 43.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 37 kB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 830 kB 37.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 35.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 488 kB 32.9 MB/s eta 0:00:01
# ...
#   Created wheel for chances: filename=chances-0.1.9-py3-none-any.whl size=41612 sha256=31718bd1d49a46606d12ce792953e35dceb296c7d9ba55a5b2080bc2cc8c7062
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/70/fa/0a/9d05780b37a3e4002d4074bc306744d986ca462becbb0ec266
# ...
