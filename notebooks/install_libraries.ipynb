# %%
# !pip install --upgrade pip
# !pip uninstall -y enum34
#!pip install --upgrade pyproj pandas shapely geopandas dask_ml joblib scikit-learn==0.22.2.post1 dask[dataframe]==2.12.0 distributed==2.12.0 lz4==3.0.2 blosc==1.8.3 cloudpickle==1.3.0 msgpack==1.0.0 numpy==1.18.1 toolz==0.10.0 tornado==6.0.4 imbalanced-learn pyzmq
# !pip install --upgrade pyproj pandas shapely geopandas dask_ml joblib scikit-learn==0.23.0 dask[dataframe]==2.12.0 distributed==2.12.0 lz4==3.0.2 blosc==1.8.3 cloudpickle==1.3.0 msgpack==1.0.0 numpy==1.18.1 toolz==0.10.0 tornado==6.0.4 imbalanced-learn pyzmq
# Out:
# ...
#     100% |████████████████████████████████| 1.5MB 18.8MB/s ta 0:00:01
# ...
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# ...
# Found existing installation: enum34 1.1.9
# Uninstalling enum34-1.1.9:
#   Successfully uninstalled enum34-1.1.9
# ...
#      |████████████████████████████████| 10.9 MB 15.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.0 MB 64.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.8 MB 61.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 928 kB 50.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 140 kB 70.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 294 kB 54.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.3 MB 54.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 789 kB 61.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 601 kB 32.3 MB/s eta 0:00:01
# ...

# %%
# !pip install --upgrade keras==2.1.5 tensorflow==2.0
# Out:
# ...
#      |████████████████████████████████| 334 kB 11.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 86.3 MB 73.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 50 kB 12.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 2.2 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 104 kB 66.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.8 MB 44.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 2.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 9.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 449 kB 50.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.8 MB 63.8 MB/s eta 0:00:01
# ...
#   Using cached requests-2.23.0-py2.py3-none-any.whl (58 kB)
# ...
#      |████████████████████████████████| 88 kB 14.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 89 kB 14.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 68.0 MB/s eta 0:00:01
# ...
